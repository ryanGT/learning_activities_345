# %% [markdown]
# ## Finding Phase Lag using FFT

# %%
import matplotlib.pyplot as plt
import numpy as np
import control
from numpy import sin, cos, tan, pi
from control import TransferFunction as TF

# %% [markdown]
# ### Problem Statement
#
# Use FFT to find the phase lag for the fixed sine test in this csv file listed below.
#
# - zoom in on two neighboring peaks and verify the answer

# %%
data = np.loadtxt("fixed_sine_data.csv", delimiter=",", skiprows=1)

# %%
t = data[:,0]
u = data[:,1]
y = data[:,2]

# %%
plt.figure()
plt.plot(t,u,t,y)

# %% [markdown]
# ## Step 1: Truncate the Data
#
# We need to truncate the data for two reasons:
#
# 1. We need to keep only the steady-state data, so we need to chop off the part with transients in it.
# 2. We need the data we send to the FFT function to be periodic, so it must have an integer number of periods.
#
# There are 500 samples per second.  If you estimate the period from the graph, you can determine the number of data points per period.  Create truncated data arrays that contain the last 2-4 periods of data.

# %% [markdown]
# ## Step 2: Find the Peak Frequency Based on the FFT
#
# - scale your FFT correctly
# - find the corresponding frequency vector
# - verify that the peak frequency is correct by estimating the frequency from the data
# - the FFT should have near zero values at all other frequencies (because this is a pure sine wave with only one frequency)

# %% [markdown]
# ## Step 3: Find the Phase of the Input and Output Signals from the FFT

# %% [markdown]
# ## Step 4: Find the Phase Lag by Subtracting the Phases of the Input and Output

# %% [markdown]
# - verify that the phase lag is correct by zooming in on one period and estimating the phase from the time-domain graph
