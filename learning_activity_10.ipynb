# %% [markdown]
# # Learning Activity 10

# %%
import matplotlib.pyplot as plt
import numpy as np
import control
from numpy import sin, cos, tan, pi
from control import TransferFunction as TF
import random_bode_generator as rbg

# %%
p1 = 1*2*pi
p2 = 5*2*pi
p3 = 20*2*pi

# %%
part1 = TF(p1,[1,p1])

# %%
part2 = TF(p2,[1,p2])

# %%
part3 = TF(p3,[1,p3])

# %%
G = part1*part2*part3

# %%
G
# Out:
# TransferFunction(array([24805.02134424]), array([1.00000000e+00, 1.63362818e+02, 4.93480220e+03, 2.48050213e+04]))

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# Build on your solution to LA 9 to create a lead + lag compensator for the plant above.  Your goal is to minimize the $\pm1\%$ settling time while keeping the overshoot less than 10%.  Note that for this assignment, your final value must be within 1% of the desired output (i.e. the final value for a unit step input must be within 0.99 to 1.01).
